# %%
import pandas as pd

# %%
olympics = pd.read_csv('./olympics.csv')
olympics.rename(columns=olympics.iloc[0], inplace=True)
olympics.rename(columns=['Pays', '№ Summer', '01!', '02!', '03!', 'Total', '№ Winter', '01!', '02!', '03!', 'Total','№ Games', '01!', '02!', '03!', 'Combined Total'])
olympics = olympics[1:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-9f667b7a858c> in <module>
#       1 olympics = pd.read_csv('./olympics.csv')
#       2 olympics.rename(columns=olympics.iloc[0], inplace=True)
# ----> 3 olympics.rename(columns=['Pays', '№ Summer', '01!', '02!', '03!', 'Total', '№ Winter', '01!', '02!', '03!', 'Total','№ Games', '01!', '02!', '03!', 'Combined Total'])
#       4 olympics = olympics[1:]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     185         @wraps(func)
#     186         def wrapper(*args, **kwargs):
# --> 187             return func(*args, **kwargs)
#     188
#     189         if not PY2:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in rename(self, *args, **kwargs)
#    3779         kwargs.pop('axis', None)
#    3780         kwargs.pop('mapper', None)
# ...

# %%
olympics.head()
# Out:
#                        NaN № Summer 01 ! 02 ! 03 ! Total № Winter 01 ! 02 !  \
# 1        Afghanistan (AFG)       13    0    0    2     2        0    0    0
# 2            Algeria (ALG)       12    5    2    8    15        3    0    0
# 3          Argentina (ARG)       23   18   24   28    70       18    0    0
# 4            Armenia (ARM)        5    1    2    9    12        6    0    0
# 5  Australasia (ANZ) [ANZ]        2    3    4    5    12        0    0    0
#
#   03 ! Total № Games 01 ! 02 ! 03 ! Combined total
# 1    0     0      13    0    0    2              2
# 2    0     0      15    5    2    8             15
# 3    0     0      41   18   24   28             70
# 4    0     0      11    1    2    9             12
# 5    0     0       2    3    4    5             12

# %% [markdown]
# -  Display countries which have won a least one gold medal
# -  Display countries which have won only medals in Winter medal
# -
